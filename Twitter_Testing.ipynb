# %%
import tweepy
import numpy as np 
import pandas

# %%
client = tweepy.Client(consumer_key="SSztsRMPznWWpDcUgEfqQQN45",
                       consumer_secret="5UxjLmK1T3CjJdTZLrfhDpPdYpxXLwjIC3hsY2UR0VNwVFqile",
                       access_token="1529595920228175872-XirhVrCIEj01S1jjsrUbLZGjlz34gM",
                       access_token_secret="SBiidOZJNEoY1cShfm1MTg7XURZEsNL8M2Rg6f3BGaBt1",
                       bearer_token='AAAAAAAAAAAAAAAAAAAAAHUYdAEAAAAAArS%2BeEXavDIzZdUxf1IGGlkWEPo%3D8SGEbaxKML39c1SX8i1zSlt2zMdvegC6yLm8BYES5x9PfTHIW6')

client.create_tweet(text = "Hello, my name is Alex. I will be creating a series to understand the Twitter API in Python. Link in bio for more detailed tutorials.")


def ref_tweet(tweets):

    length = len(tweets)

    for i in range(length):
    
        tweet = tweets.data[i-1]

        if tweet.referenced_tweets is None:
        
            tweet_t = tweet.referenced_tweets
            return 'No Referenced Tweet'
            #print(type(tweet_t))
            #print("This is a none object")
        
        else: 
            tweet_t = tweet.referenced_tweets
            return str(tweet.referenced_tweets)
            # print(tweet_t[i-1]['id'])
            #print(type(tweet_t))
            #print("this is an object")

# %%
## FINAL CODE FOR CREATING DATA FRAME

def ref_tweet(tweets):

    length = len(tweets)

    for i in range(length):
    
        tweet = tweets.data[i-1]

        if tweet.referenced_tweets is None:
        
            tweet_t = tweet.referenced_tweets
            return 'No Referenced Tweet'
            #print(type(tweet_t))
            #print("This is a none object")
        
        else: 
            tweet_t = tweet.referenced_tweets
            return str(tweet.referenced_tweets)
            # print(tweet_t[i-1]['id'])
            #print(type(tweet_t))
            #print("this is an object")

alex = client.get_user(username='VibeCheckBot')
alex_id = alex.data.id

tweets = client.get_users_mentions(id=alex_id, expansions=['referenced_tweets.id', 'author_id'] )
tweets_p = tweets.data

df = pd.DataFrame(data=[[tweet.id, tweet.text, tweet.author_id] for tweet in tweets_p], columns=['Tweet_id', 'Tweet_text', 'Author_id'])
df.tail(10)

df['referenced_tweet_id'] = np.array([tweet.referenced_tweets for tweet in tweets_p], dtype=list)

#df['referenced_tweet_id'] = np.nanmean(np.array([tweet.referenced_tweets for tweet in tweets_p], ignore_None=True))

#df['referenced_tweet_id'] = 

df1 = pd.DataFrame([tweet.referenced_tweets for tweet in tweets_p if tweet.referenced_tweets is not None], columns=['Name'])
df1.tail(1)
#series = pd.Series([tweet.referenced_tweets for tweet in tweets_p if tweet.referenced_tweets is not None])

#df.tail(10)

#print9
# Out:
#          Name
# 0  (type, id)

# %%
def get_referenced_tweets(tweet):
    return tweet.referenced_tweets[0]['id']

alex = client.get_user(username='VibeCheckBot')
alex_id = alex.data.id

tweets = client.get_users_mentions(id=alex_id, expansions=['referenced_tweets.id', 'author_id'] )

tweet = tweets.data[0]

tweet_tiny = tweet.referenced_tweets
tweet_tiny[0]["id"]


#tweet_tiny
#tweet.id

#print(tweet)

tweet_x = tweets.data

tweets_df = pd.DataFrame.from_dict(tweet_x)
tweets_df.tail(10)
#tweet_x

# tweets_reply_df = pd.DataFrame.from_dict(tweet.referenced_tweets)
# tweets_reply_df.tail(10)

# print(dir(tweets.data[0]))
type(tweet_tiny)
#type(tweet)
tweet
print(dir(tweets.data[0]))
#print(tweet_tiny[0])

tweet_tiny = tweet.referenced_tweets
tweet_tiny[0]["id"]

#np.dtype(tweet_tiny)
type(tweet_tiny)
#tweet.referenced_tweets.tail(10)
# Out:
# ['__abstractmethods__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '_abc_impl', 'attachments', 'author_id', 'context_annotations', 'conversation_id', 'created_at', 'data', 'entities', 'geo', 'get', 'id', 'in_reply_to_user_id', 'items', 'keys', 'lang', 'non_public_metrics', 'organic_metrics', 'possibly_sensitive', 'promoted_metrics', 'public_metrics', 'referenced_tweets', 'reply_settings', 'source', 'text', 'values', 'withheld']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\alexs\DataWithAlex_Github\VibeCheckBot_Final\Twitter_Testing.ipynb Cell 4' in <cell line: 41>()
#      <a href='vscode-notebook-cell:/c%3A/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/Twitter_Testing.ipynb#ch0000002?line=38'>39</a> #np.dtype(tweet_tiny)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/Twitter_Testing.ipynb#ch0000002?line=39'>40</a> type(tweet_tiny)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/Twitter_Testing.ipynb#ch0000002?line=40'>41</a> tweet.referenced_tweets.tail(10)
#
# AttributeError: 'list' object has no attribute 'tail'

# %%
def get_referenced_tweets(tweets):

    #tweet = tweets.data[0]
    #tweet_tiny = tweet.referenced_tweets
    #tweet_tiny[0]["id"]

    length = len(tweets)

    for index in range(length):
        tweet_s = tweets.data[index]
        tweet_t = tweet_s.referenced_tweets
        print(tweet_t[index]['id'])

alex = client.get_user(username='VibeCheckBot')
alex_id = alex.data.id

tweets = client.get_users_mentions(id=alex_id, expansions=['referenced_tweets.id', 'author_id'] )

# tweet = tweets.data[0]
# tweet_tiny = tweet.referenced_tweets
# tweet_tiny[0]["id"]
# tweets_0 = tweets.data

#get_referenced_tweets(tweets)
#len(tweets)
length = len(tweets)

for i in range(length):
    
    tweet = tweets.data[i-1]

    if tweet.referenced_tweets is None:
        
        tweet_t = tweet.referenced_tweets
        print(type(tweet_t))
        print("This is a none object")
        
    else: 
        tweet_t = tweet.referenced_tweets
        # print(tweet_t[i-1]['id'])
        print(type(tweet_t))
        print("this is an object")
    

    #if(tweet.referenced_tweets)
    #print(tweet.referenced_tweets)
    print(type(tweet.referenced_tweets))
    #tweet_t = tweet.referenced_tweets
    #print(tweet_t[0]['id'])
    #tweet_t[index]['id']
# Out:
# <class 'NoneType'>
# This is a none object
# <class 'NoneType'>
# <class 'list'>
# this is an object
# <class 'list'>
# <class 'NoneType'>
# This is a none object
# <class 'NoneType'>
# <class 'NoneType'>
# This is a none object
# <class 'NoneType'>

# %%
alex = client.get_user(username='VibeCheckBot')
alex_id = alex.data.id

tweets = client.get_users_mentions(id=alex_id, expansions=['referenced_tweets.id', 'author_id'] )

tweet_s = tweets.data[0]
tweet_t = tweet.referenced_tweets
print(tweet_t[0]['id'])
len(tweets)
# Out:
# 1530040908837752842
# 4

# %%
# tweet.data['referenced_tweets']
tweets = client.get_users_mentions(id=alex_id, expansions=['referenced_tweets.id', 'author_id'] )
tweets_p = tweets.data


#tweet.referenced_tweets[0] for tweet in tweets_p:
    #print(tweet.referenced_tweets[tweet.referenced_tweets.index])

#for i, tweet in tweets_p.items():
   # print(tweet.referenced_tweets[i]['id'])
# df = pd.DataFrame(data=[for tweet in tweets_p], columns=['Tweets'])

#for i, print(tweet.referenced_tweets[i]['id'] for tweet in tweets_p:
    #print(tweet.referenced_tweets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\alexs\DataWithAlex_Github\VibeCheckBot_Final\Twitter_Testing.ipynb Cell 4' in <cell line: 16>()
#       <a href='vscode-notebook-cell:/c%3A/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/Twitter_Testing.ipynb#ch0000009?line=2'>3</a> tweets_p = tweets.data
#       <a href='vscode-notebook-cell:/c%3A/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/Twitter_Testing.ipynb#ch0000009?line=5'>6</a> #tweet.referenced_tweets[0] for tweet in tweets_p:
#       <a href='vscode-notebook-cell:/c%3A/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/Twitter_Testing.ipynb#ch0000009?line=6'>7</a>     #print(tweet.referenced_tweets[tweet.referenced_tweets.index])
#       <a href='vscode-notebook-cell:/c%3A/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/Twitter_Testing.ipynb#ch0000009?line=7'>8</a>
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/Twitter_Testing.ipynb#ch0000009?line=12'>13</a> #for i, print(tweet.referenced_tweets[i]['id'] for tweet in tweets_p:
#      <a href='vscode-notebook-cell:/c%3A/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/Twitter_Testing.ipynb#ch0000009?line=13'>14</a>     #print(tweet.referenced_tweets)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/Twitter_Testing.ipynb#ch0000009?line=15'>16</a> index(tweets_p)
#
# NameError: name 'index' is not defined

# %%
# FINAL TEST POPULATING PANDAS WITH TWEETS
import numpy as np 
alex = client.get_user(username='VibeCheckBot')
alex_id = alex.data.id

tweets = client.get_users_mentions(id=alex_id, expansions=['referenced_tweets.id', 'author_id'] )
tweets_p = tweets.data

def get_referenced_tweets(tweet):
    tweet_tiny = tweet.referenced_tweets
    return tweet_tiny[0]["id"]

# df = pd.DataFrame(data=[tweet.referenced_tweets[tweet.index]['id'] for tweet in tweets_p], columns=['Tweets'])
# df = pd.DataFrame(data=[get_referenced_tweets(tweet) for tweet in tweets_p], columns=['Tweets'])
df = pd.DataFrame(data=[[tweet.text, tweet.id] for tweet in tweets_p], columns=['Tweets', 'Tweet_id'])


# df = pd.DataFrame(data=[tweet.referenced_tweets for tweet in tweets_p], columns=['Tweets'])
# df['referenced_tweet_id'] = np.array([tweet.referenced_tweets for tweet in tweets_p], columns=['Ref_Tweet_ID', 'replied_to'])
# df['referenced_tweet_id'] = np.array([tweet.referenced_tweets for tweet in tweets_p], columns=['Ref_Tweet_ID', 'replied_to'])

df.tail(10)
#tweets_p

#tweet.text for tweet in tweets_p
# tweets_p[0]
# Out:
#                                               Tweets             Tweet_id
# 0  @VibeCheckBot We are testing this out @VibeChe...  1530234331897253888
# 1           vibe check: This is a test @VibeCheckBot  1530040908837752842
# 2           Check my vibes, vibe check @VibeCheckBot  1529866870471503872
# 3  I think the vibe bot is finally up and running...  1529862461213507584
# 4         Have a great day, vibe check @VibeCheckBot  1529846756908859392
# 5           this is a test, vibe check @VibeCheckBot  1529845706776883200
# 6                    Hello, vibe check @VibeCheckBot  1529682036235161602
# 7  never take it by twenty one pilots , vibe chec...  1528954282292260866
# 8  We only eat Birthday Cake , vibe check @vibech...  1528841470224093184
# 9  The quick brown fox jumped over the lazy dog, ...  1528840350177140738

# %%
## Exploring how to turn tweet objects from tweepy into dataframes

import pandas as pd

alex = client.get_user(username='VibeCheckBot')
alex_id = alex.data.id

tweets = client.get_users_mentions(id=alex_id, expansions=['referenced_tweets.id'] )

tweets_df = pd.DataFrame.from_dict(tweets.data)
tweets_df.tail(10)

tweets_reply_df = pd.DataFrame.from_dict(tweet.referenced_tweets)
tweets_reply_df.tail(10)
# Out:
#                     id        type
# 0  1530040908837752842  replied_to

# %%
## Uploading data to and from google sheets using 
## https://erikrood.com/Posts/py_gsheets.html

# pip install pygsheets
import pygsheets
import pandas as pd

#authorization
gc = pygsheets.authorize(service_file='/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/vibecheckbot-351521-6255c4712ef6.json')

alex = client.get_user(username='VibeCheckBot')
alex_id = alex.data.id

tweets = client.get_users_mentions(id=alex_id, expansions=['referenced_tweets.id'] )

tweets_df = pd.DataFrame.from_dict(tweets.data)
tweets_df.tail(10)

sh = gc.open('VibeCheckBot')

#select the first sheet 
wks = sh[0]

#update the first sheet with df, starting at cell B2. 
wks.set_dataframe(tweets_df,(1,1))

# %%
tweets_df.tail(10)
# Out:
#                     id referenced_tweets  \
# 0  1530234331897253888      [(type, id)]
# 1  1530040908837752842               NaN
# 2  1529866870471503872               NaN
# 3  1529862461213507584               NaN
# 4  1529846756908859392               NaN
# 5  1529845706776883200               NaN
# 6  1529682036235161602               NaN
# 7  1528954282292260866               NaN
# 8  1528841470224093184               NaN
# 9  1528840350177140738               NaN
#
#                                                 text
# 0  @VibeCheckBot We are testing this out @VibeChe...
# 1           vibe check: This is a test @VibeCheckBot
# 2           Check my vibes, vibe check @VibeCheckBot
# 3  I think the vibe bot is finally up and running...
# 4         Have a great day, vibe check @VibeCheckBot
# 5           this is a test, vibe check @VibeCheckBot
# 6                    Hello, vibe check @VibeCheckBot
# 7  never take it by twenty one pilots , vibe chec...
# 8  We only eat Birthday Cake , vibe check @vibech...
# 9  The quick brown fox jumped over the lazy dog, ...

# %%
# %pip install pygsheets
import pygsheets
import pandas as pd

#authorization
gc = pygsheets.authorize(service_file='/Users/alexs/DataWithAlex_Github/VibeCheckBot_Final/vibecheckbot-351521-6255c4712ef6.json')

# Create empty dataframe
df = pd.DataFrame()

# Create a column
df['name'] = ['Brian', 'Brandon', 'Alex']

#open the google spreadsheet (where 'PY to Gsheet Test' is the name of my sheet)
sh = gc.open('VibeCheckBot')

#select the first sheet 
wks = sh[0]

#update the first sheet with df, starting at cell B2. 
wks.set_dataframe(df,(1,1))
